# %%
# Import necessary libraries
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report, accuracy_score

# %%
# Load the training dataset and testing dataset
train_data = pd.read_csv('UNSW_NB15_training-set.csv')
test_data = pd.read_csv('UNSW_NB15_testing-set.csv')

attack_cat_mapping = {
    0: 'Normal',
    1: 'Analysis',
    2: 'Backdoor',
    3: 'DoS',
    4: 'Exploits',
    5: 'Fuzzers',
    6: 'Generic',
    7: 'Reconnaissance',
    8: 'Shellcode',
    9: 'Worms'
}

# %%
train_data.head()
# Out:
#    id       dur proto service state  spkts  dpkts  sbytes  dbytes  \
# 0   1  0.000011   udp       -   INT      2      0     496       0
# 1   2  0.000008   udp       -   INT      2      0    1762       0
# 2   3  0.000005   udp       -   INT      2      0    1068       0
# 3   4  0.000006   udp       -   INT      2      0     900       0
# 4   5  0.000010   udp       -   INT      2      0    2126       0
#
#           rate  ...  ct_dst_sport_ltm  ct_dst_src_ltm  is_ftp_login  \
# 0   90909.0902  ...                 1               2             0
# 1  125000.0003  ...                 1               2             0
# 2  200000.0051  ...                 1               3             0
# 3  166666.6608  ...                 1               3             0
# 4  100000.0025  ...                 1               3             0
#
#    ct_ftp_cmd  ct_flw_http_mthd  ct_src_ltm  ct_srv_dst  is_sm_ips_ports  \
# 0           0                 0           1           2                0
# ...

# %%
train_data.describe()
# Out:
#                  id           dur         spkts         dpkts        sbytes  \
# count  82332.000000  82332.000000  82332.000000  82332.000000  8.233200e+04
# mean   41166.500000      1.006756     18.666472     17.545936  7.993908e+03
# std    23767.345519      4.710444    133.916353    115.574086  1.716423e+05
# min        1.000000      0.000000      1.000000      0.000000  2.400000e+01
# 25%    20583.750000      0.000008      2.000000      0.000000  1.140000e+02
# 50%    41166.500000      0.014138      6.000000      2.000000  5.340000e+02
# 75%    61749.250000      0.719360     12.000000     10.000000  1.280000e+03
# max    82332.000000     59.999989  10646.000000  11018.000000  1.435577e+07
#
#              dbytes          rate          sttl          dttl         sload  \
# count  8.233200e+04  8.233200e+04  82332.000000  82332.000000  8.233200e+04
# mean   1.323379e+04  8.241089e+04    180.967667     95.713003  6.454902e+07
# ...

# %%
test_data.describe()
# Out:
#                   id            dur          spkts          dpkts  \
# count  175341.000000  175341.000000  175341.000000  175341.000000
# mean    87671.000000       1.359389      20.298664      18.969591
# std     50616.731112       6.480249     136.887597     110.258271
# min         1.000000       0.000000       1.000000       0.000000
# 25%     43836.000000       0.000008       2.000000       0.000000
# 50%     87671.000000       0.001582       2.000000       2.000000
# 75%    131506.000000       0.668069      12.000000      10.000000
# max    175341.000000      59.999989    9616.000000   10974.000000
#
#              sbytes        dbytes          rate           sttl           dttl  \
# count  1.753410e+05  1.753410e+05  1.753410e+05  175341.000000  175341.000000
# mean   8.844844e+03  1.492892e+04  9.540619e+04     179.546997      79.609567
# std    1.747656e+05  1.436542e+05  1.654010e+05     102.940011     110.506863
# ...

# %%
#Data preprocessing
# drop unnecessary columns
train_data = train_data.drop(columns=["id"], axis=1)
test_data = test_data.drop(columns=["id"], axis=1)

# %%
#encoding
categorical_columns = ["proto", "service", "state", "attack_cat"]
for col in categorical_columns:
    train_data[col] = LabelEncoder().fit_transform(train_data[col])
    test_data[col] = LabelEncoder().fit_transform(test_data[col])

# %%
#handling missing values
train_data = train_data.fillna(0)
test_data = test_data.fillna(0)

# %%
#splitting the training data and testing data into X and Y features.
X_train = train_data.drop('attack_cat', axis=1)
y_train = train_data['attack_cat']
X_test = test_data.drop('attack_cat', axis=1)
y_test = test_data['attack_cat']

# %%
#Creating our Random Forrest Classigier.
from sklearn.model_selection import train_test_split, GridSearchCV

#Hyperparameter Tuning using GridSearchCV
param_grid = {
    'n_estimators': [100, 200, 300],
    'max_depth': [None, 10, 20, 30],
    'min_samples_split': [2, 5, 10]
}

clf = GridSearchCV(RandomForestClassifier(random_state=42), param_grid, cv=5, n_jobs=-1)
clf.fit(X_train, y_train)

#Get the best hyperparameters from the grid search
best_params = clf.best_params_

#Training the model with the best hyperparameters
best_clf = RandomForestClassifier(**best_params, random_state=42)
best_clf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=20, n_estimators=200, random_state=42)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix

#Making predictions on the testing data
y_pred = best_clf.predict(X_test)

#Evaluating the model
accuracy = accuracy_score(y_test, y_pred)
report = classification_report(y_test, y_pred)

print("Accuracy:", accuracy)
conf_matrix = confusion_matrix(y_test, y_pred)

#Print the classification report
print("Classification Report:\n", report)

#Print the confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Accuracy: 0.8483868576088879
# ...

# %%
import random
#Print 10 random packets with actual and predicted categories
print("Randomly Selected Packets:")
random_indices = random.sample(range(len(y_test)), 10)  # Randomly select 10 indices
for i in random_indices:
    actual_category = attack_cat_mapping[y_test.iloc[i]]
    predicted_category = attack_cat_mapping[y_pred[i]]
    print(f"Packet {i + 1}: Actual Category - {actual_category}, Predicted Category - {predicted_category}")
# Out:
# Randomly Selected Packets:
# Packet 26535: Actual Category - Generic, Predicted Category - Generic
# Packet 134182: Actual Category - Reconnaissance, Predicted Category - Reconnaissance
# Packet 38468: Actual Category - Generic, Predicted Category - Generic
# Packet 58373: Actual Category - Backdoor, Predicted Category - Backdoor
# Packet 60716: Actual Category - Reconnaissance, Predicted Category - DoS
# Packet 66408: Actual Category - Generic, Predicted Category - Generic
# Packet 138792: Actual Category - Fuzzers, Predicted Category - Fuzzers
# Packet 34556: Actual Category - Generic, Predicted Category - Generic
# Packet 61026: Actual Category - Exploits, Predicted Category - DoS
# Packet 122565: Actual Category - Fuzzers, Predicted Category - Fuzzers
